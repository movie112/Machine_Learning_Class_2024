# %% [markdown]
# # Isotropic Diffusion via Heat Equation

# %% [markdown]
# ## import library

# %%
import numpy as np
import matplotlib.image as img
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import util_solution as util

# %% [markdown]
# ## load image

# %%
I_color = img.imread('04_image.jpeg')   # load image

# %% [markdown]
# ## visualize the input image in color

# %%
plt.figure(figsize=(8,8))
plt.imshow(I_color)
plt.title('input image in color')
plt.axis('off')
plt.show()

# %% [markdown]
# ## check the size of image

# %%
dim_height  = I_color.shape[0]
dim_width   = I_color.shape[1]
dim_channel = I_color.shape[2]
print('height=', dim_height, ', width=', dim_width, ', channel=', dim_channel)
# Out:
# height= 512 , width= 512 , channel= 3

# %% [markdown]
# ## convert the input image into gray scale by taking the average over the channel

# %%
I_gray = util.convert_color_to_gray(I_color)

# %% [markdown]
# ## normalize the gray-scale image into the range [0, 1]

# %%
I_norm = util.normalize_01(I_gray)

# %%
val_min = np.min(I_norm)
val_max = np.max(I_norm)
print('min=', val_min, ', max=', val_max)
# Out:
# min= 0.0 , max= 1.0

# %% [markdown]
# ## visualize the input image in gray

# %%
plt.figure(figsize=(8,8))
plt.imshow(I_norm, cmap='gray', vmin=0, vmax=1)
plt.title('input image in gray scale')
plt.axis('off')
plt.show()

# %% [markdown]
# ## apply the heat equation on the image data with different diffusion times

# %%
delta_t     = 0.1 
num_iter1   = 10
out1        = util.compute_heat_equation(I_norm, delta_t, num_iter1)

# %%
def plot_01():
    plt.figure(figsize=(8,8))
    plt.imshow(out1, cmap='gray')
    plt.axis('off')
    plt.show()
    print('sum =', out1.sum())

# %%
plot_01()
# Out:
# sum = 117372.14814814818

# %%
delta_t     = 0.1 
num_iter2   = 100
out2        = util.compute_heat_equation(I_norm, delta_t, num_iter2)

# %%
def plot_02():
    plt.figure(figsize=(8,8))
    plt.imshow(out2, cmap='gray')
    plt.axis('off')
    plt.show()
    print('sum =', out2.sum())

# %%
plot_02()
# Out:
# sum = 117372.14814814818

# %%
delta_t     = 0.1 
num_iter3   = 1000
out3        = util.compute_heat_equation(I_norm, delta_t, num_iter3)

# %%
def plot_03():
    plt.figure(figsize=(8,8))
    plt.imshow(out3, cmap='gray')
    plt.axis('off')
    plt.show()
    print('sum =', out3.sum())

# %%
plot_03()
# Out:
# sum = 117372.14814814816

# %%
delta_t     = 0.1 
num_iter4   = 10000
out4        = util.compute_heat_equation(I_norm, delta_t, num_iter4)

# %%
def plot_04():
    plt.figure(figsize=(8,8))
    plt.imshow(out4, cmap='gray')
    plt.axis('off')
    plt.show()
    print('sum =', out4.sum())

# %%
plot_04()
# Out:
# sum = 117372.14814814815

# %% [markdown]
# ## compute the $L_2^2$-norm of the gradient on the smooth images

# %%
out5 = util.compute_norm_gradient_central(out1)

# %%
def plot_05():
    plt.figure(figsize=(8,8))
    plt.imshow(out5, cmap='gray')
    plt.axis('off')
    plt.show()
    print('sum =', out5.sum())

# %%
plot_05()
# Out:
# sum = 224.37335994207493

# %%
out6 = util.compute_norm_gradient_central(out2)

# %%
def plot_06():
    plt.figure(figsize=(8,8))
    plt.imshow(out6, cmap='gray')
    plt.axis('off')
    plt.show()
    print('sum =', out6.sum())

# %%
plot_06()
# Out:
# sum = 53.673501140393505

# %%
out7 = util.compute_norm_gradient_central(out3)

# %%
def plot_07():
    plt.figure(figsize=(8,8))
    plt.imshow(out7, cmap='gray')
    plt.axis('off')
    plt.show()
    print('sum =', out7.sum())

# %%
plot_07()
# Out:
# sum = 7.535816800164009

# %%
out8 = util.compute_norm_gradient_central(out4)

# %%
def plot_08():
    plt.figure(figsize=(8,8))
    plt.imshow(out8, cmap='gray')
    plt.axis('off')
    plt.show()
    print('sum =', out8.sum())

# %%
plot_08()
# Out:
# sum = 0.5113652935574515

# %% [markdown]
# ---
# ---

# %% [markdown]
# # results

# %% [markdown]
# ---
# ---

# %%
number_result = 8

for i in range(number_result):
    title           = '# RESULT # {:02d}'.format(i+1)
    name_function   = 'plot_{:02d}()'.format(i+1)

    print('')
    print('################################################################################')
    print(title)
    print('################################################################################')
    print('') 

    eval(name_function)
# Out:
# ################################################################################
# # RESULT # 01
# ################################################################################
# sum = 117372.14814814818
#
# ################################################################################
# # RESULT # 02
# ################################################################################
# sum = 117372.14814814818
#
# ################################################################################
# # RESULT # 03
# ################################################################################
# sum = 117372.14814814816
#
# ################################################################################
# # RESULT # 04
# ################################################################################
# sum = 117372.14814814815
#
# ################################################################################
# # RESULT # 05
# ...
